# %%
import pandas as pd
import mysql.connector

csv_files = [
    ("KTCL_bus_info.csv", "Goa"),
    ("WB_bus_info.csv", "West Bengal"),
    ("NB_bus_info.csv", "Nagaland"),
    ("JK_bus_info.csv", "Jammu and Kashmir"),
    ("KAAC_bus_info.csv", "Assam"),
    ("PUNJAB_bus_info.csv", "Punjab"),
    ("CTU_bus_info.csv", "Chandigarh"),
    ("ASTC_bus_info.csv", "Assam"),
    ("HRTC_bus_info.csv", "Himachal Pradesh"),
    ("SBSTC_bus_info.csv", "West Bengal")
]

# Reading and adding CSV's to DataFrame
df_list = []
for file, state in csv_files:
    df = pd.read_csv(file)
    df['State'] = state 
    df_list.append(df)

# Concatenate all DataFrames
result_df = pd.concat(df_list, ignore_index=True)

# Data cleaning
result_df['Price'] = result_df['Price'].str.replace('INR ', '', regex=False)
result_df = result_df.dropna()
result_df.insert(0, 'id', range(1, len(result_df) + 1))

# Save cleaned data to a CSV
result_df.to_csv("bus_routes_cleaned.csv", index=False)

# Database connection
my_connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='3008',
    auth_plugin='mysql_native_password'
)

my_cursor = my_connection.cursor()

# Creating the database 
my_cursor.execute("CREATE DATABASE IF NOT EXISTS redbus")

# Switch to new database
my_cursor.execute("USE redbus")

# Creating the table 
my_cursor.execute("""
CREATE TABLE IF NOT EXISTS bus_routes (
    id INT PRIMARY KEY,
    Route_Name TEXT,
    Route_Link TEXT,                            
    Bus_Name TEXT,
    Bus_Type TEXT,
    Departing_Time TEXT,
    Duration TEXT,
    Reaching_Time TEXT,
    Star_Rating TEXT,
    Price TEXT,
    Seat_Availability TEXT,
    State TEXT 
)
""")
expected_columns = ['id', 'Route_Name', 'Route_Link', 'Bus_Name', 'Bus_Type', 'Departing_Time', 'Duration', 'Reaching_Time', 'Star_Rating', 'Price', 'Seat_Availability', 'State']
result_df = result_df[expected_columns]

# Inserting cleaned data into the database
for index, row in result_df.iterrows():
    try:
        print(f"Inserting row {index}: {tuple(row)}")  
        my_cursor.execute("""
        INSERT INTO bus_routes (id, Route_Name, Route_Link, Bus_Name, Bus_Type, Departing_Time, Duration, Reaching_Time, Star_Rating, Price, Seat_Availability, State) 
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        """, tuple(row))
    except mysql.connector.IntegrityError as err:
        if "1062" in str(err):  # Duplicate entry error
            print(f"Duplicate entry for row {index}, skipping.")
        else:
            print(f"Error inserting row {index}: {err}")

# Commit and close the connection
my_connection.commit()
my_cursor.close()
my_connection.close()
# Out:
# Inserting row 0: (1, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'IntrCity SmartBus', 'Bharat Benz A/C Seater /Sleeper (2+1)', '21:00', '11h 05m', '08:05', 4.4, '609', '18 Seats available', 'Goa')
# Duplicate entry for row 0, skipping.
# Inserting row 1: (2, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Ashray Amrutyog', 'A/C Sleeper (2+1)', '22:00', '11h 30m', '09:30', 4.0, '900', '18 Seats available', 'Goa')
# Duplicate entry for row 1, skipping.
# Inserting row 2: (3, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Ashray Travels', 'Non A/C Seater / Sleeper (2+1)', '21:15', '10h 30m', '07:45', 4.2, '500', '15 Seats available', 'Goa')
# Duplicate entry for row 2, skipping.
# Inserting row 3: (4, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Ashray Vip Yellows', 'A/C Sleeper (2+1)', '20:30', '11h 30m', '08:00', 4.1, '900', '15 Seats available', 'Goa')
# Duplicate entry for row 3, skipping.
# Inserting row 4: (5, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Ashray Travels', 'Bharat Benz A/C Sleeper (2+1)', '21:00', '12h 00m', '09:00', 4.3, '900', '14 Seats available', 'Goa')
# Duplicate entry for row 4, skipping.
# Inserting row 5: (6, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Gogte Travels', 'NON A/C Sleeper (1+2)', '19:30', '10h 45m', '06:15', 4.0, '699', '21 Seats available', 'Goa')
# Duplicate entry for row 5, skipping.
# Inserting row 6: (7, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Dolphin Travel House (37)', 'Bharat Benz A/C Sleeper (2+1)', '19:45', '10h 15m', '06:00', 4.4, '910', '16 Seats available', 'Goa')
# Duplicate entry for row 6, skipping.
# Inserting row 7: (8, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'AdGogte Anand Travels', 'Volvo Multi-Axle I-Shift A/C Sleeper (2+1)', '23:30', '12h 00m', '11:30', 4.6, '1000', '9 Seats available', 'Goa')
# Duplicate entry for row 7, skipping.
# Inserting row 8: (9, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Ashray Grand', 'Volvo Multi-Axle A/C Sleeper (2+1)', '23:05', '10h 25m', '09:30', 4.1, '1000', '27 Seats available', 'Goa')
# Duplicate entry for row 8, skipping.
# Inserting row 9: (10, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Prasanna - Purple Bus', 'VE A/C Sleeper (2+1)', '22:30', '11h 00m', '09:30', 4.1, '920', '23 Seats available', 'Goa')
# Duplicate entry for row 9, skipping.
# Inserting row 10: (11, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'IntrCity SmartBus', 'A/C Sleeper (2+1)', '22:30', '11h 20m', '09:50', 4.3, '909', '11 Seats available', 'Goa')
# Duplicate entry for row 10, skipping.
# Inserting row 11: (12, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Prasanna - Purple Bus', 'VE A/C Sleeper (2+1)', '22:15', '11h 15m', '09:30', 4.1, '1020', '22 Seats available', 'Goa')
# Duplicate entry for row 11, skipping.
# Inserting row 12: (13, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Indumati Travels', 'A/C Sleeper (2+1)', '22:20', '10h 10m', '08:30', 4.1, '902', '20 Seats available', 'Goa')
# Duplicate entry for row 12, skipping.
# Inserting row 13: (14, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '22:00', '11h 05m', '09:05', 4.3, '909', '9 Seats available', 'Goa')
# Duplicate entry for row 13, skipping.
# Inserting row 14: (15, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Zingbus Plus', 'Bharat Benz A/C Sleeper (2+1)', '23:00', '11h 25m', '10:25', 4.1, '899', '20 Seats available', 'Goa')
# Duplicate entry for row 14, skipping.
# Inserting row 15: (16, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Ashray National Express', 'NON A/C Sleeper (2+1)', '20:00', '10h 45m', '06:45', 4.1, '700', '15 Seats available', 'Goa')
# Duplicate entry for row 15, skipping.
# Inserting row 16: (17, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Atmaram Gobus', 'VE A/C Sleeper (2+1)', '22:30', '10h 15m', '08:45', 4.7, '900', '10 Seats available', 'Goa')
# Duplicate entry for row 16, skipping.
# Inserting row 17: (18, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '21:55', '10h 25m', '08:20', 4.0, '909', '19 Seats available', 'Goa')
# Duplicate entry for row 17, skipping.
# Inserting row 18: (19, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '23:30', '10h 20m', '09:50', 4.5, '909', '7 Seats available', 'Goa')
# Duplicate entry for row 18, skipping.
# Inserting row 19: (20, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Atmaram Gobus', 'VE A/C Sleeper (2+1)', '21:00', '10h 30m', '07:30', 4.7, '900', '7 Seats available', 'Goa')
# Duplicate entry for row 19, skipping.
# Inserting row 20: (21, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Gogte Travels', 'A/C Sleeper (2+1)', '20:15', '10h 45m', '07:00', 4.1, '2910', '21 Seats available', 'Goa')
# Duplicate entry for row 20, skipping.
# Inserting row 21: (22, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Gogte Shreyas', 'A/C Sleeper (2+1)', '21:45', '11h 15m', '09:00', 4.2, '899', '3 Seats available', 'Goa')
# Duplicate entry for row 21, skipping.
# Inserting row 22: (23, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Laxmi-Princess Nova', 'Non A/C Seater / Sleeper (2+1)', '20:00', '11h 15m', '07:15', 4.0, '500', '6 Seats available', 'Goa')
# Duplicate entry for row 22, skipping.
# Inserting row 23: (24, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '22:05', '11h 05m', '09:10', 4.3, '1009', '11 Seats available', 'Goa')
# Duplicate entry for row 23, skipping.
# Inserting row 24: (25, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Gogte Travels', 'A/C Sleeper (2+1)', '20:15', '11h 30m', '07:45', 5.0, '2910', '21 Seats available', 'Goa')
# Duplicate entry for row 24, skipping.
# Inserting row 25: (26, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Humsafar Travels', 'A/C Sleeper (2+1)', '22:15', '11h 00m', '09:15', 4.1, '950', '21 Seats available', 'Goa')
# Duplicate entry for row 25, skipping.
# Inserting row 26: (27, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Anand Tours And Travels', 'Volvo Multi-Axle A/C Sleeper (2+1)', '22:30', '10h 00m', '08:30', 4.0, '2900', '36 Seats available', 'Goa')
# Duplicate entry for row 26, skipping.
# Inserting row 27: (28, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Anand Tours And Travels', 'Volvo Multi-Axle A/C Sleeper (2+1)', '22:30', '11h 15m', '09:45', 4.0, '2900', '36 Seats available', 'Goa')
# Duplicate entry for row 27, skipping.
# Inserting row 28: (29, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Ashray Atmaram Divine', 'NON A/C Sleeper (1+2)', '19:45', '11h 00m', '06:45', 3.9, '700', '17 Seats available', 'Goa')
# Duplicate entry for row 28, skipping.
# Inserting row 29: (30, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Atmaram Gobus', 'NON A/C Sleeper (2+1)', '20:30', '10h 30m', '07:00', 3.8, '700', '17 Seats available', 'Goa')
# Duplicate entry for row 29, skipping.
# Inserting row 30: (31, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Laxmi Queen Asta', 'A/C Sleeper (2+1)', '21:30', '10h 30m', '08:00', 3.7, '900', '16 Seats available', 'Goa')
# Duplicate entry for row 30, skipping.
# Inserting row 31: (32, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Traveltime Travels (Kelkar)', 'NON A/C Seater/ Sleeper (2+1)', '21:00', '12h 40m', '09:40', 3.2, '500', '13 Seats available', 'Goa')
# Duplicate entry for row 31, skipping.
# Inserting row 32: (33, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Humsafar Travels', 'A/C Sleeper (2+1)', '22:50', '10h 40m', '09:30', 3.4, '950', '21 Seats available', 'Goa')
# Duplicate entry for row 32, skipping.
# Inserting row 33: (34, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Shreyash Travels', 'Bharat Benz A/C Sleeper (2+1)', '21:45', '10h 45m', '08:30', 3.5, '909', '13 Seats available', 'Goa')
# Duplicate entry for row 33, skipping.
# Inserting row 34: (35, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Laxmi Queen Prime', 'A/C Sleeper (2+1)', '20:30', '11h 00m', '07:30', 3.8, '900', '14 Seats available', 'Goa')
# Duplicate entry for row 34, skipping.
# Inserting row 35: (36, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Dolphin Travel House (38)', 'Bharat Benz A/C Sleeper (2+1)', '20:30', '11h 00m', '07:30', 3.9, '910', '19 Seats available', 'Goa')
# Duplicate entry for row 35, skipping.
# Inserting row 36: (37, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Abhishek Vishal Travels (Samarth)', 'A/C Sleeper (2+1)', '00:15', '10h 00m', '10:15', 3.7, '900', '25 Seats available', 'Goa')
# Duplicate entry for row 36, skipping.
# Inserting row 37: (38, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Prasanna - Purple Bus', 'VE A/C Sleeper (2+1)', '21:45', '11h 30m', '09:15', 3.3, '1020', '22 Seats available', 'Goa')
# Duplicate entry for row 37, skipping.
# Inserting row 38: (39, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Dolphin travel house', 'A/C Sleeper (2+1)', '23:45', '11h 00m', '10:45', 3.0, '910', '22 Seats available', 'Goa')
# Duplicate entry for row 38, skipping.
# Inserting row 39: (40, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'PSR Travels Goa', 'A/C Sleeper (2+1)', '23:45', '09h 30m', '09:15', 3.5, '800', '18 Seats available', 'Goa')
# Duplicate entry for row 39, skipping.
# Inserting row 40: (41, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Humsafar Travels', 'A/C Sleeper (2+1)', '22:15', '10h 45m', '09:00', 3.4, '950', '22 Seats available', 'Goa')
# Duplicate entry for row 40, skipping.
# Inserting row 41: (42, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Dolphin Travel House (39)', 'A/C Sleeper (2+1)', '21:45', '11h 15m', '09:00', 2.6, '717', '18 Seats available', 'Goa')
# Duplicate entry for row 41, skipping.
# Inserting row 42: (43, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Gogte Travels (Manish)', 'Non AC Seater (2+2)', '19:20', '12h 10m', '07:30', 2.8, '500', '23 Seats available', 'Goa')
# Duplicate entry for row 42, skipping.
# Inserting row 43: (44, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Mascot Travels(Patil)', 'A/C Sleeper (2+1)', '21:45', '11h 30m', '09:15', 1.7, '1000', '24 Seats available', 'Goa')
# Duplicate entry for row 43, skipping.
# Inserting row 44: (45, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Abhishek Vishal Travels', 'A/C Sleeper (2+1)', '23:00', '09h 40m', '08:40', 2.3, '1000', '24 Seats available', 'Goa')
# Duplicate entry for row 44, skipping.
# Inserting row 45: (46, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Maa tours & Travels', 'A/C Seater (2+2)', '23:29', '10h 31m', '10:00', 1.0, '1800', '20 Seats available', 'Goa')
# Duplicate entry for row 45, skipping.
# Inserting row 46: (47, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Kokan Holidays', 'NON A/C Seater Push Back (2+2)', '21:30', '12h 15m', '09:45', 1.1, '2925', '2 Seats available', 'Goa')
# Duplicate entry for row 46, skipping.
# Inserting row 47: (48, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'PVS Tours and Travels', 'A/C Sleeper (2+1)', '00:30', '09h 45m', '10:15', 1.0, '1200', '30 Seats available', 'Goa')
# Duplicate entry for row 47, skipping.
# Inserting row 48: (49, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Manish Travel', 'A/C Sleeper (2+1)', '23:55', '10h 04m', '09:59', 1.0, '900', '27 Seats available', 'Goa')
# Duplicate entry for row 48, skipping.
# Inserting row 49: (50, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Shubhra Sharma Tourist Services', 'A/C Sleeper (2+1)', '00:10', '10h 21m', '10:31', 2.5, '800', '22 Seats available', 'Goa')
# Duplicate entry for row 49, skipping.
# Inserting row 50: (51, 'Pune to Goa', 'https://www.redbus.in/bus-tickets/pune-to-goa', 'Shubhra Sharma Tourist Services', 'A/C Sleeper (2+1)', '00:10', '10h 21m', '10:31', 1.0, '1000', '17 Seats available', 'Goa')
# Duplicate entry for row 50, skipping.
# Inserting row 51: (52, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Kadamba Transport Corporation Limited (KTCL) - 89820', 'A/C Sleeper (2+1)', '19:00', '12h 00m', '07:00', 3.1, '800', '19 Seats available', 'Goa')
# Duplicate entry for row 51, skipping.
# Inserting row 52: (53, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Ashray Travels', 'Non A/C Seater / Sleeper (2+1)', '20:00', '10h 30m', '06:30', 4.4, '500', '35 Seats available', 'Goa')
# Duplicate entry for row 52, skipping.
# Inserting row 53: (54, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'IntrCity SmartBus', 'Bharat Benz A/C Seater /Sleeper (2+1)', '20:30', '10h 00m', '06:30', 4.6, '609', '33 Seats available', 'Goa')
# Duplicate entry for row 53, skipping.
# Inserting row 54: (55, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'AdIndumati Travels', 'A/C Sleeper (2+1)', '21:00', '10h 00m', '07:00', 4.1, '900', '19 Seats available', 'Goa')
# Duplicate entry for row 54, skipping.
# Inserting row 55: (56, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'IntrCity SmartBus', 'A/C Sleeper (2+1)', '18:00', '10h 00m', '04:00', 4.5, '909', '18 Seats available', 'Goa')
# Duplicate entry for row 55, skipping.
# Inserting row 56: (57, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Ashray Travels', 'Bharat Benz A/C Sleeper (2+1)', '22:30', '11h 30m', '10:00', 4.3, '900', '14 Seats available', 'Goa')
# Duplicate entry for row 56, skipping.
# Inserting row 57: (58, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Gobus', 'NON A/C Sleeper (2+1)', '17:46', '12h 15m', '06:01', 4.0, '699', '17 Seats available', 'Goa')
# Duplicate entry for row 57, skipping.
# Inserting row 58: (59, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Laxmi-Princess Nova', 'Non A/C Seater / Sleeper (2+1)', '19:00', '11h 30m', '06:30', 4.0, '500', '21 Seats available', 'Goa')
# Duplicate entry for row 58, skipping.
# Inserting row 59: (60, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Ashray Grand', 'Volvo Multi-Axle A/C Sleeper (2+1)', '22:00', '11h 30m', '09:30', 4.0, '1000', '24 Seats available', 'Goa')
# Duplicate entry for row 59, skipping.
# Inserting row 60: (61, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Zingbus Plus', 'VE A/C Sleeper (2+1)', '21:05', '10h 00m', '07:05', 4.6, '909', '20 Seats available', 'Goa')
# Duplicate entry for row 60, skipping.
# Inserting row 61: (62, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '19:00', '10h 00m', '05:00', 4.3, '909', '13 Seats available', 'Goa')
# Duplicate entry for row 61, skipping.
# Inserting row 62: (63, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '19:30', '10h 10m', '05:40', 4.4, '909', '19 Seats available', 'Goa')
# Duplicate entry for row 62, skipping.
# Inserting row 63: (64, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '18:30', '10h 55m', '05:25', 4.4, '1009', '26 Seats available', 'Goa')
# Duplicate entry for row 63, skipping.
# Inserting row 64: (65, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Rajdhani Travels Corporation', 'VE A/C Sleeper (2+1)', '18:00', '12h 10m', '06:10', 4.6, '1000', '24 Seats available', 'Goa')
# Duplicate entry for row 64, skipping.
# Inserting row 65: (66, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Prasanna - Purple Bus', 'VE A/C Sleeper (2+1)', '17:00', '12h 00m', '05:00', 4.1, '920', '25 Seats available', 'Goa')
# Duplicate entry for row 65, skipping.
# Inserting row 66: (67, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Amrutyog Travels', 'A/C Sleeper (2+1)', '19:00', '11h 22m', '06:22', 4.0, '900', '27 Seats available', 'Goa')
# Duplicate entry for row 66, skipping.
# Inserting row 67: (68, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Prasanna - Purple Bus', 'VE A/C Sleeper (2+1)', '22:15', '09h 30m', '07:45', 4.1, '925', '22 Seats available', 'Goa')
# Duplicate entry for row 67, skipping.
# Inserting row 68: (69, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Ashray Travels', 'Volvo Multi-Axle Sleeper A/C (2+1)', '22:45', '11h 10m', '09:55', 4.1, '1000', '26 Seats available', 'Goa')
# Duplicate entry for row 68, skipping.
# Inserting row 69: (70, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Gobus', 'VE A/C Sleeper (2+1)', '21:32', '09h 30m', '07:02', 4.7, '900', '6 Seats available', 'Goa')
# Duplicate entry for row 69, skipping.
# Inserting row 70: (71, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '21:00', '10h 05m', '07:05', 4.4, '909', '20 Seats available', 'Goa')
# Duplicate entry for row 70, skipping.
# Inserting row 71: (72, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels (Dolphin)', 'A/C Sleeper (2+1)', '15:30', '09h 30m', '01:00', 4.0, '1000', '9 Seats available', 'Goa')
# Duplicate entry for row 71, skipping.
# Inserting row 72: (73, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'IntrCity SmartBus', 'A/C Sleeper (2+1)', '21:30', '10h 00m', '07:30', 4.4, '909', '9 Seats available', 'Goa')
# Duplicate entry for row 72, skipping.
# Inserting row 73: (74, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Prasanna - Purple Bus', 'VE A/C Sleeper (2+1)', '22:00', '09h 30m', '07:30', 4.0, '905', '23 Seats available', 'Goa')
# Duplicate entry for row 73, skipping.
# Inserting row 74: (75, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Gobus', 'NON A/C Sleeper (2+1)', '18:46', '12h 15m', '07:01', 4.0, '700', '24 Seats available', 'Goa')
# Duplicate entry for row 74, skipping.
# Inserting row 75: (76, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels ( Ashray )', 'A/C Sleeper (2+1)', '22:02', '12h 08m', '10:10', 4.0, '900', '27 Seats available', 'Goa')
# Duplicate entry for row 75, skipping.
# Inserting row 76: (77, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'PVS Tours and Travels', 'A/C Sleeper (2+1)', '20:00', '10h 00m', '06:00', 4.5, '3000', '15 Seats available', 'Goa')
# Duplicate entry for row 76, skipping.
# Inserting row 77: (78, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Ashray Travels', 'Volvo Multi Axle A/C Sleeper I-Shift B11R (2+1)', '21:00', '10h 15m', '07:15', 3.8, '1000', '27 Seats available', 'Goa')
# Duplicate entry for row 77, skipping.
# Inserting row 78: (79, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels (Shreyas)', 'Bharat Benz A/C Sleeper (2+1)', '20:03', '10h 30m', '06:33', 3.7, '900', '23 Seats available', 'Goa')
# Duplicate entry for row 78, skipping.
# Inserting row 79: (80, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Zingbus Plus', 'Bharat Benz A/C Sleeper (2+1)', '18:10', '11h 20m', '05:30', 4.0, '900', '23 Seats available', 'Goa')
# Duplicate entry for row 79, skipping.
# Inserting row 80: (81, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Prasanna - Purple Bus', 'VE A/C Sleeper (2+1)', '18:00', '12h 15m', '06:15', 3.8, '920', '28 Seats available', 'Goa')
# Duplicate entry for row 80, skipping.
# Inserting row 81: (82, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels ( Gogte )', 'NON A/C Sleeper (2+1)', '21:15', '10h 30m', '07:45', 3.5, '700', '24 Seats available', 'Goa')
# Duplicate entry for row 81, skipping.
# Inserting row 82: (83, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Laxmi Queen Prime', 'A/C Sleeper (2+1)', '19:30', '11h 00m', '06:30', 3.9, '900', '22 Seats available', 'Goa')
# Duplicate entry for row 82, skipping.
# Inserting row 83: (84, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Laxmi Empress Stellar', 'NON A/C Sleeper (2+1)', '19:45', '11h 00m', '06:45', 3.9, '700', '20 Seats available', 'Goa')
# Duplicate entry for row 83, skipping.
# Inserting row 84: (85, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels (Humsafar)', 'Bharat Benz A/C Sleeper (2+1)', '19:30', '09h 30m', '05:00', 3.8, '900', '22 Seats available', 'Goa')
# Duplicate entry for row 84, skipping.
# Inserting row 85: (86, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'National Travels,Goa', 'NON A/C Sleeper (2+1)', '19:00', '11h 20m', '06:20', 3.7, '700', '20 Seats available', 'Goa')
# Duplicate entry for row 85, skipping.
# Inserting row 86: (87, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels (Dolphin)', 'A/C Sleeper (2+1)', '15:30', '11h 00m', '02:30', 3.7, '1000', '9 Seats available', 'Goa')
# Duplicate entry for row 86, skipping.
# Inserting row 87: (88, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels(GTA)', 'A/C Sleeper (2+1)', '19:00', '11h 00m', '06:00', 3.7, '1000', '27 Seats available', 'Goa')
# Duplicate entry for row 87, skipping.
# Inserting row 88: (89, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels (Dolphin)', 'A/C Sleeper (2+1)', '16:30', '11h 55m', '04:25', 3.5, '1000', '26 Seats available', 'Goa')
# Duplicate entry for row 88, skipping.
# Inserting row 89: (90, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Giroba Travels (Kelkar)', 'Non A/C Seater / Sleeper (2+1)', '17:45', '11h 45m', '05:30', 3.2, '500', '32 Seats available', 'Goa')
# Duplicate entry for row 89, skipping.
# Inserting row 90: (91, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Giroba Travels (Kelkar)', 'NON A/C Airbus (2+2)', '18:00', '11h 30m', '05:30', 3.8, '500', '35 Seats available', 'Goa')
# Duplicate entry for row 90, skipping.
# Inserting row 91: (92, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '20:00', '10h 15m', '06:15', 3.8, '909', '27 Seats available', 'Goa')
# Duplicate entry for row 91, skipping.
# Inserting row 92: (93, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels(M.Dev)', 'A/C Sleeper (2+1)', '22:00', '10h 00m', '08:00', 3.7, '1000', '30 Seats available', 'Goa')
# Duplicate entry for row 92, skipping.
# Inserting row 93: (94, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Ashray Travels', 'Volvo Multi-Axle A/C Sleeper (2+1)', '20:00', '12h 05m', '08:05', 3.8, '1000', '9 Seats available', 'Goa')
# Duplicate entry for row 93, skipping.
# Inserting row 94: (95, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels (Unity)', 'A/C Sleeper (2+1)', '20:00', '11h 00m', '07:00', 3.7, '1999', '27 Seats available', 'Goa')
# Duplicate entry for row 94, skipping.
# Inserting row 95: (96, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels (Dolphin)', 'AC Sleeper (2+1)', '18:30', '11h 00m', '05:30', 3.4, '1000', '20 Seats available', 'Goa')
# Duplicate entry for row 95, skipping.
# Inserting row 96: (97, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels (Dolphin)', 'A/C Sleeper (2+1)', '19:30', '13h 10m', '08:40', 3.9, '1000', '22 Seats available', 'Goa')
# Duplicate entry for row 96, skipping.
# Inserting row 97: (98, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'PSR Travels Goa', 'A/C Sleeper (2+1)', '19:15', '10h 45m', '06:00', 3.4, '900', '18 Seats available', 'Goa')
# Duplicate entry for row 97, skipping.
# Inserting row 98: (99, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'VAILANKANNI TRAVELS', 'VE A/C Sleeper (2+1)', '18:30', '12h 25m', '06:55', 3.7, '1000', '30 Seats available', 'Goa')
# Duplicate entry for row 98, skipping.
# Inserting row 99: (100, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'PSR Travels (Vaibhav)', 'A/C Sleeper (2+1)', '22:30', '09h 00m', '07:30', 3.9, '1000', '23 Seats available', 'Goa')
# Duplicate entry for row 99, skipping.
# Inserting row 100: (101, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels (Vaibhav)', 'A/C Sleeper (2+1)', '22:31', '10h 00m', '08:31', 2.9, '1000', '23 Seats available', 'Goa')
# Duplicate entry for row 100, skipping.
# Inserting row 101: (102, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Jolly Tours and Travels', 'A/C Sleeper (2+1)', '18:30', '11h 15m', '05:45', 3.5, '1000', '28 Seats available', 'Goa')
# Duplicate entry for row 101, skipping.
# Inserting row 102: (103, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Manish Roshan Travels', 'A/C Sleeper (2+1)', '19:00', '11h 30m', '06:30', 2.4, '1000', '28 Seats available', 'Goa')
# Duplicate entry for row 102, skipping.
# Inserting row 103: (104, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Atmaram Travels (Vishal)', 'A/C Sleeper (2+1)', '16:35', '14h 20m', '06:55', 2.8, '1000', '27 Seats available', 'Goa')
# Duplicate entry for row 103, skipping.
# Inserting row 104: (105, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Manish Sharma Travels', 'A/C Sleeper (2+1)', '17:30', '11h 30m', '05:00', 1.8, '1000', '24 Seats available', 'Goa')
# Duplicate entry for row 104, skipping.
# Inserting row 105: (106, 'Goa to Pune', 'https://www.redbus.in/bus-tickets/goa-to-pune', 'Anand Tours And Travels', 'Volvo Multi-Axle A/C Sleeper (2+1)', '20:00', '10h 00m', '06:00', 5.0, '2900', '36 Seats available', 'Goa')
# Duplicate entry for row 105, skipping.
# Inserting row 106: (107, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Kadamba Transport Corporation Limited (KTCL) - 97386', 'Volvo AC Seater Pushback 2+2', '17:00', '13h 00m', '06:00', 3.8, '800', '15 Seats available', 'Goa')
# Duplicate entry for row 106, skipping.
# Inserting row 107: (108, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '19:35', '14h 15m', '09:50', 4.5, '1009', '7 Seats available', 'Goa')
# Duplicate entry for row 107, skipping.
# Inserting row 108: (109, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '16:00', '16h 20m', '08:20', 4.4, '1009', '18 Seats available', 'Goa')
# Duplicate entry for row 108, skipping.
# Inserting row 109: (110, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'AdIntrCity SmartBus', 'AC Sleeper (2+1)', '20:25', '13h 50m', '10:15', 4.1, '1009', '9 Seats available', 'Goa')
# Duplicate entry for row 109, skipping.
# Inserting row 110: (111, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Dolphin travel house', 'Bharat Benz A/C Sleeper (2+1)', '21:30', '15h 45m', '13:15', 4.3, '1010', '14 Seats available', 'Goa')
# Duplicate entry for row 110, skipping.
# Inserting row 111: (112, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Zingbus Plus', 'VE A/C Sleeper (2+1)', '20:00', '18h 00m', '14:00', 4.6, '1000', '22 Seats available', 'Goa')
# Duplicate entry for row 111, skipping.
# Inserting row 112: (113, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Abhishek Vishal Travels', 'A/C Sleeper (2+1)', '16:00', '16h 40m', '08:40', 5.0, '1000', '24 Seats available', 'Goa')
# Duplicate entry for row 112, skipping.
# Inserting row 113: (114, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'AdKonkan Travels Mujawar', 'NON A/C Sleeper (2+1)', '18:50', '16h 55m', '11:45', 3.9, '800', '15 Seats available', 'Goa')
# Duplicate entry for row 113, skipping.
# Inserting row 114: (115, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Atmaram Manish Travels', 'A/C Sleeper (2+1)', '17:00', '16h 15m', '09:15', 5.0, '1000', '10 Seats available', 'Goa')
# Duplicate entry for row 114, skipping.
# Inserting row 115: (116, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '17:00', '16h 10m', '09:10', 4.5, '1009', '11 Seats available', 'Goa')
# Duplicate entry for row 115, skipping.
# Inserting row 116: (117, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Mascot Travels(M.Dev)', 'A/C Sleeper (2+1)', '19:00', '17h 00m', '12:00', 4.1, '1000', '13 Seats available', 'Goa')
# Duplicate entry for row 116, skipping.
# Inserting row 117: (118, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Dolphin Travel House (37)', 'Bharat Benz A/C Sleeper (2+1)', '15:25', '14h 35m', '06:00', 4.1, '1010', '17 Seats available', 'Goa')
# Duplicate entry for row 117, skipping.
# Inserting row 118: (119, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Dolphin Travel House (38)', 'Bharat Benz A/C Sleeper (2+1)', '15:25', '16h 05m', '07:30', 4.2, '1010', '22 Seats available', 'Goa')
# Duplicate entry for row 118, skipping.
# Inserting row 119: (120, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Zingbus Plus', 'Bharat Benz A/C Sleeper (2+1)', '17:00', '17h 25m', '10:25', 4.3, '1000', '20 Seats available', 'Goa')
# Duplicate entry for row 119, skipping.
# Inserting row 120: (121, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Shubhra Sharma Tourist Services', 'A/C Sleeper (2+1)', '18:30', '16h 01m', '10:31', 4.3, '1000', '17 Seats available', 'Goa')
# Duplicate entry for row 120, skipping.
# Inserting row 121: (122, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Abhishek Vishal Travels', 'NON A/C Push Back (2+2)', '15:30', '15h 40m', '07:10', 4.0, '600', '33 Seats available', 'Goa')
# Duplicate entry for row 121, skipping.
# Inserting row 122: (123, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Global Travel Agency (GTA)', 'A/C Sleeper (2+1)', '17:50', '18h 40m', '12:30', 4.1, '1000', '23 Seats available', 'Goa')
# Duplicate entry for row 122, skipping.
# Inserting row 123: (124, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Mascot Travels(Patil)', 'A/C Sleeper (2+1)', '16:00', '17h 15m', '09:15', 4.0, '1000', '19 Seats available', 'Goa')
# Duplicate entry for row 123, skipping.
# Inserting row 124: (125, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Atmaram Manish Travels', 'A/C Sleeper (2+1)', '17:10', '16h 15m', '09:25', 4.0, '1000', '12 Seats available', 'Goa')
# Duplicate entry for row 124, skipping.
# Inserting row 125: (126, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Naik Tours And Travels', 'NON A/C Sleeper (2+1)', '15:25', '15h 20m', '06:45', 3.5, '800', '19 Seats available', 'Goa')
# Duplicate entry for row 125, skipping.
# Inserting row 126: (127, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Dolphin Travel House (39)', 'A/C Sleeper (2+1)', '15:45', '16h 45m', '08:30', 3.2, '1010', '18 Seats available', 'Goa')
# Duplicate entry for row 126, skipping.
# Inserting row 127: (128, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Shubham Vailankanni Travels', 'VE A/C Sleeper (2+1)', '20:30', '15h 35m', '12:05', 3.6, '1000', '18 Seats available', 'Goa')
# Duplicate entry for row 127, skipping.
# Inserting row 128: (129, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Mascot Travels(M.Dev)', 'A/C Sleeper (2+1)', '17:30', '17h 15m', '10:45', 3.7, '1000', '24 Seats available', 'Goa')
# Duplicate entry for row 128, skipping.
# Inserting row 129: (130, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Konkan Travels National', 'NON A/C Sleeper (2+1)', '19:25', '14h 20m', '09:45', 3.9, '800', '8 Seats available', 'Goa')
# Duplicate entry for row 129, skipping.
# Inserting row 130: (131, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Shubham Saijyoti Travels', 'A/C Sleeper (2+1)', '19:15', '15h 45m', '11:00', 3.1, '1000', '19 Seats available', 'Goa')
# Duplicate entry for row 130, skipping.
# Inserting row 131: (132, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Sanvi Travels - Shree', 'A/C Sleeper (2+1)', '17:00', '16h 30m', '09:30', 3.5, '1000', '14 Seats available', 'Goa')
# Duplicate entry for row 131, skipping.
# Inserting row 132: (133, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Anand Travels', 'NON A/C Sleeper (2+1)', '19:00', '13h 00m', '08:00', 3.1, '700', '12 Seats available', 'Goa')
# Duplicate entry for row 132, skipping.
# Inserting row 133: (134, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Dolphin travel house', 'A/C Sleeper (2+1)', '17:45', '17h 00m', '10:45', 3.3, '1010', '22 Seats available', 'Goa')
# Duplicate entry for row 133, skipping.
# Inserting row 134: (135, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Abhishek Vishal Travels (Samarth)', 'A/C Sleeper (2+1)', '17:20', '16h 55m', '10:15', 3.4, '1000', '25 Seats available', 'Goa')
# Duplicate entry for row 134, skipping.
# Inserting row 135: (136, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Dolphin Travel House (40)', 'A/C Sleeper (2+1)', '20:00', '17h 15m', '13:15', 3.3, '1010', '20 Seats available', 'Goa')
# Duplicate entry for row 135, skipping.
# Inserting row 136: (137, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Dolphin travel house', 'A/C Sleeper (2+1)', '19:15', '17h 00m', '12:15', 3.2, '1010', '20 Seats available', 'Goa')
# Duplicate entry for row 136, skipping.
# Inserting row 137: (138, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Shubham Vailankanni Travels', 'VE A/C Sleeper (2+1)', '17:45', '16h 45m', '10:30', 3.4, '3000', '29 Seats available', 'Goa')
# Duplicate entry for row 137, skipping.
# Inserting row 138: (139, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Atmaram Manish Travels', 'NON A/C Seater (2+2)', '15:25', '16h 20m', '07:45', 1.0, '600', '27 Seats available', 'Goa')
# Duplicate entry for row 138, skipping.
# Inserting row 139: (140, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'PVS Tours and Travels', 'A/C Sleeper (2+1)', '18:30', '16h 30m', '11:00', 2.6, '1200', '30 Seats available', 'Goa')
# Duplicate entry for row 139, skipping.
# Inserting row 140: (141, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Naik Travels (Syndicate)', 'NON A/C Sleeper (2+1)', '18:00', '16h 32m', '10:32', 1.0, '800', '20 Seats available', 'Goa')
# Duplicate entry for row 140, skipping.
# Inserting row 141: (142, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Manish Travels', 'NON A/C Seater (2+2)', '15:25', '16h 05m', '07:30', 2.6, '600', '31 Seats available', 'Goa')
# Duplicate entry for row 141, skipping.
# Inserting row 142: (143, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Atmaram Travels', 'NON A/C Sleeper (2+1)', '16:15', '16h 15m', '08:30', 2.5, '800', '11 Seats available', 'Goa')
# Duplicate entry for row 142, skipping.
# Inserting row 143: (144, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Manish Travel', 'A/C Sleeper (2+1)', '18:30', '15h 59m', '10:29', 1.0, '1000', '27 Seats available', 'Goa')
# Duplicate entry for row 143, skipping.
# Inserting row 144: (145, 'Mumbai to Goa', 'https://www.redbus.in/bus-tickets/mumbai-to-goa', 'Maa tours & Travels', 'A/C Seater (2+2)', '17:00', '17h 30m', '10:30', 2.4, '1800', '20 Seats available', 'Goa')
# Duplicate entry for row 144, skipping.
# Inserting row 145: (146, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Shanta Travels', 'NON A/C Sleeper (2+1)', '19:30', '12h 45m', '08:15', 4.1, '1810', '7 Seats available', 'Goa')
# Duplicate entry for row 145, skipping.
# Inserting row 146: (147, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'VKV Travels', 'A/C Sleeper (2+1)', '22:55', '11h 05m', '10:00', 4.0, '2196', '9 Seats available', 'Goa')
# Duplicate entry for row 146, skipping.
# Inserting row 147: (148, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Limousine Tours & Travels', 'A/C Sleeper (2+1)', '21:00', '12h 20m', '09:20', 4.2, '2374', '14 Seats available', 'Goa')
# Duplicate entry for row 147, skipping.
# Inserting row 148: (149, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Streamline tours and travels', 'A/C Sleeper (2+1)', '21:00', '13h 00m', '10:00', 4.0, '2580', '5 Seats available', 'Goa')
# Duplicate entry for row 148, skipping.
# Inserting row 149: (150, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '20:30', '14h 10m', '10:40', 3.6, '2399', '1 Seat available', 'Goa')
# Duplicate entry for row 149, skipping.
# Inserting row 150: (151, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Streamline tours and travels', 'A/C Sleeper (2+1)', '23:00', '13h 00m', '12:00', 3.0, '1799', '20 Seats available', 'Goa')
# Duplicate entry for row 150, skipping.
# Inserting row 151: (152, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Rajat Travels', 'A/C Seater / Sleeper (2+1)', '20:15', '12h 30m', '08:45', 3.8, '1387', '2 Seats available', 'Goa')
# Duplicate entry for row 151, skipping.
# Inserting row 152: (153, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Streamline tours and travels', 'A/C Sleeper (2+1)', '22:20', '12h 55m', '11:15', 3.0, '2180', '11 Seats available', 'Goa')
# Duplicate entry for row 152, skipping.
# Inserting row 153: (154, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Sri Tourist', 'A/C Sleeper (2+1)', '20:15', '13h 17m', '09:32', 3.6, '1799', '2 Seats available', 'Goa')
# Duplicate entry for row 153, skipping.
# Inserting row 154: (155, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Jolly Tours and Travels', 'A/C Sleeper (2+1)', '20:45', '11h 00m', '07:45', 3.3, '2200', '9 Seats available', 'Goa')
# Duplicate entry for row 154, skipping.
# Inserting row 155: (156, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Sea Bird Tourist', 'NON A/C Sleeper (2+1)', '18:00', '13h 00m', '07:00', 3.1, '1800', '3 Seats available', 'Goa')
# Duplicate entry for row 155, skipping.
# Inserting row 156: (157, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Sea Bird Tourist', 'NON A/C Sleeper (2+1)', '20:30', '13h 30m', '10:00', 3.9, '1800', '5 Seats available', 'Goa')
# Duplicate entry for row 156, skipping.
# Inserting row 157: (158, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Sugama Tourist', 'NON A/C Sleeper (2+1)', '20:30', '12h 15m', '08:45', 3.7, '1900', '2 Seats available', 'Goa')
# Duplicate entry for row 157, skipping.
# Inserting row 158: (159, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Sugama Tourist', 'NON A/C Sleeper (2+1)', '20:30', '11h 15m', '07:45', 3.9, '1900', '2 Seats available', 'Goa')
# Duplicate entry for row 158, skipping.
# Inserting row 159: (160, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'SRS Travels', 'NON AC Seater / Sleeper 2+1', '20:00', '13h 15m', '09:15', 2.8, '2099', '27 Seats available', 'Goa')
# Duplicate entry for row 159, skipping.
# Inserting row 160: (161, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Jolly Tours and Travels', 'A/C Sleeper (2+1)', '21:00', '12h 00m', '09:00', 2.6, '2300', '11 Seats available', 'Goa')
# Duplicate entry for row 160, skipping.
# Inserting row 161: (162, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Anand Travels', 'NON A/C Sleeper (2+1)', '19:00', '12h 00m', '07:00', 1.0, '1910', '5 Seats available', 'Goa')
# Duplicate entry for row 161, skipping.
# Inserting row 162: (163, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Bharathi Travels', 'A/C Sleeper (2+1)', '23:15', '12h 15m', '11:30', 2.3, '1899', '16 Seats available', 'Goa')
# Duplicate entry for row 162, skipping.
# Inserting row 163: (164, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Sea Bird Tourist', 'A/C Sleeper (2+1)', '22:15', '13h 00m', '11:15', 2.5, '2300', '14 Seats available', 'Goa')
# Duplicate entry for row 163, skipping.
# Inserting row 164: (165, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Sea Bird Tourist', 'A/C Sleeper (2+1)', '21:15', '13h 00m', '10:15', 2.7, '2300', '9 Seats available', 'Goa')
# Duplicate entry for row 164, skipping.
# Inserting row 165: (166, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'VRL Travels', 'A/C Sleeper (2+1)', '21:00', '13h 45m', '10:45', 2.3, '2600', '2 Seats available', 'Goa')
# Duplicate entry for row 165, skipping.
# Inserting row 166: (167, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Sea Bird Tourist', 'Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)', '22:30', '13h 00m', '11:30', 2.0, '2000', '9 Seats available', 'Goa')
# Duplicate entry for row 166, skipping.
# Inserting row 167: (168, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'SRS Travels', 'NON AC Seater / Sleeper 2+1', '20:00', '12h 30m', '08:30', 2.5, '2099', '27 Seats available', 'Goa')
# Duplicate entry for row 167, skipping.
# Inserting row 168: (169, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'Sugama Tourist', 'NON A/C Sleeper (2+1)', '20:30', '11h 45m', '08:15', 3.7, '1900', '1 Seat available', 'Goa')
# Duplicate entry for row 168, skipping.
# Inserting row 169: (170, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'VRL Travels', 'NON A/C Sleeper (2+1)', '20:00', '13h 30m', '09:30', 2.7, '1800', '9 Seats available', 'Goa')
# Duplicate entry for row 169, skipping.
# Inserting row 170: (171, 'Bangalore to Goa', 'https://www.redbus.in/bus-tickets/bangalore-to-goa', 'VRL Travels', 'A/C Seater / Sleeper (2+1)', '19:30', '13h 00m', '08:30', 0.0, '1300', '5 Seats available', 'Goa')
# Duplicate entry for row 170, skipping.
# Inserting row 171: (172, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Streamline tours and travels', 'A/C Sleeper (2+1)', '18:00', '12h 30m', '06:30', 4.3, '1099', '18 Seats available', 'Goa')
# Duplicate entry for row 171, skipping.
# Inserting row 172: (173, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Shanta Travels', 'NON A/C Sleeper (2+1)', '17:30', '15h 15m', '08:45', 4.1, '860', '18 Seats available', 'Goa')
# Duplicate entry for row 172, skipping.
# Inserting row 173: (174, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '19:00', '13h 35m', '08:35', 4.3, '859', '15 Seats available', 'Goa')
# Duplicate entry for row 173, skipping.
# Inserting row 174: (175, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Intercity travels', 'Bharat Benz A/C Sleeper (2+1)', '18:00', '13h 15m', '07:15', 4.5, '1199', '4 Seats available', 'Goa')
# Duplicate entry for row 174, skipping.
# Inserting row 175: (176, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Streamline tours and travels', 'A/C Sleeper (2+1)', '19:00', '12h 30m', '07:30', 4.2, '1099', '14 Seats available', 'Goa')
# Duplicate entry for row 175, skipping.
# Inserting row 176: (177, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Sunrise Tours and Travels', 'A/C Sleeper (2+1)', '18:30', '12h 40m', '07:10', 4.5, '1099', '4 Seats available', 'Goa')
# Duplicate entry for row 176, skipping.
# Inserting row 177: (178, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'IntrCity SmartBus', 'AC Sleeper (2+1)', '17:00', '13h 40m', '06:40', 4.3, '929', '6 Seats available', 'Goa')
# Duplicate entry for row 177, skipping.
# Inserting row 178: (179, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Intercity travels', 'Bharat Benz A/C Sleeper (2+1)', '17:15', '13h 15m', '06:30', 4.2, '999', '10 Seats available', 'Goa')
# Duplicate entry for row 178, skipping.
# Inserting row 179: (180, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Balaji Tourist', 'Volvo Multi-Axle A/C Semisleeper (2+2)', '20:45', '10h 40m', '07:25', 4.3, '3000', '1 Seat available', 'Goa')
# Duplicate entry for row 179, skipping.
# Inserting row 180: (181, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'VRL Travels', 'A/C Sleeper (2+1)', '20:00', '14h 00m', '10:00', 3.1, '1500', '16 Seats available', 'Goa')
# Duplicate entry for row 180, skipping.
# Inserting row 181: (182, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Sea Bird Tourist', 'A/C Sleeper (2+1)', '20:30', '13h 00m', '09:30', 3.0, '1000', '8 Seats available', 'Goa')
# Duplicate entry for row 181, skipping.
# Inserting row 182: (183, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Sugama Tourist', 'NON A/C Sleeper (2+1)', '19:45', '12h 00m', '07:45', 3.6, '1000', '10 Seats available', 'Goa')
# Duplicate entry for row 182, skipping.
# Inserting row 183: (184, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Sea Bird Tourist', 'NON A/C Sleeper (2+1)', '17:30', '14h 00m', '07:30', 3.2, '800', '20 Seats available', 'Goa')
# Duplicate entry for row 183, skipping.
# Inserting row 184: (185, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Limousine Tours & Travels', 'A/C Sleeper (2+1)', '17:05', '13h 55m', '07:00', 3.3, '998', '25 Seats available', 'Goa')
# Duplicate entry for row 184, skipping.
# Inserting row 185: (186, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Sea Bird Tourist', 'NON A/C Sleeper (2+1)', '17:00', '14h 00m', '07:00', 3.4, '800', '18 Seats available', 'Goa')
# Duplicate entry for row 185, skipping.
# Inserting row 186: (187, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Sea Bird Tourist', 'Volvo Multi-Axle I-Shift B11R Semi Sleeper (2+2)', '21:00', '12h 00m', '09:00', 3.3, '650', '28 Seats available', 'Goa')
# Duplicate entry for row 186, skipping.
# Inserting row 187: (188, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'PVS Tours and Travels', 'A/C Sleeper (2+1)', '20:05', '14h 10m', '10:15', 3.0, '3000', '32 Seats available', 'Goa')
# Duplicate entry for row 187, skipping.
# Inserting row 188: (189, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Rajat Travels', 'A/C Seater / Sleeper (2+1)', '18:00', '12h 35m', '06:35', 3.2, '3700', '42 Seats available', 'Goa')
# Duplicate entry for row 188, skipping.
# Inserting row 189: (190, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Sugama Tourist', 'NON A/C Sleeper (2+1)', '19:00', '12h 45m', '07:45', 2.6, '1000', '11 Seats available', 'Goa')
# Duplicate entry for row 189, skipping.
# Inserting row 190: (191, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Jolly Tours and Travels', 'A/C Sleeper (2+1)', '20:00', '11h 00m', '07:00', 2.7, '850', '21 Seats available', 'Goa')
# Duplicate entry for row 190, skipping.
# Inserting row 191: (192, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'Anand Travels', 'NON A/C Sleeper (2+1)', '18:30', '12h 15m', '06:45', 2.3, '675', '7 Seats available', 'Goa')
# Duplicate entry for row 191, skipping.
# Inserting row 192: (193, 'Goa to Bangalore', 'https://www.redbus.in/bus-tickets/goa-to-bangalore', 'SRS Travels', 'NON AC Seater / Sleeper 2+1', '19:00', '12h 30m', '07:30', 2.8, '699', '15 Seats available', 'Goa')
# Duplicate entry for row 192, skipping.
# ...
# Duplicate entry for row 2664, skipping.
# Inserting row 2665: (2666, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'SBSTC-DIGHA - BARASAT - 14:20 (DIGHA DEPOT) - 516', 'Non AC Seater (2+3)', '14:20', '04h 30m', '18:50', 4.1, '155', '52 Seats available', 'West Bengal')
# Duplicate entry for row 2665, skipping.
# Inserting row 2666: (2667, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'SBSTC-DIGHA - KARUNAMOYEE - A/C - 14:25 (BEL DEPOT) - 3962', 'AC Seater (2+2)', '14:25', '05h 00m', '19:25', 2.1, '360', '32 Seats available', 'West Bengal')
# Duplicate entry for row 2666, skipping.
# Inserting row 2667: (2668, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'SBSTC-DIGHA - KARUNAMOYEE - VIA - KOLKATA - 14:25 (VOLVO - 3708', 'Volvo AC Seater (2+2)', '14:25', '04h 30m', '18:55', 4.2, '410', '49 Seats available', 'West Bengal')
# Duplicate entry for row 2667, skipping.
# Inserting row 2668: (2669, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'SBSTC-DIGHA - THAKURPUR - 14:30 (DIG DEPOT) - 839', 'Non AC Seater (2+3)', '14:30', '04h 30m', '19:00', 3.8, '155', '52 Seats available', 'West Bengal')
# Duplicate entry for row 2668, skipping.
# Inserting row 2669: (2670, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'SBSTC-DIGHA - GARIA - VIA - KOLKATA - 14:40 (FALTA DEPOT - 3489', 'Non AC Seater (2+3)', '14:40', '05h 30m', '20:10', 3.5, '162', '51 Seats available', 'West Bengal')
# Duplicate entry for row 2669, skipping.
# Inserting row 2670: (2671, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'SBSTC-DIGHA - GARIA - A/C - 14:50 (DIG DEPOT) - 735', 'AC Seater (2+2)', '14:50', '04h 30m', '19:20', 2.7, '310', '37 Seats available', 'West Bengal')
# Duplicate entry for row 2670, skipping.
# Inserting row 2671: (2672, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'SBSTC-DIGHA - GARIA - VIA - KOLKATA - 15:10 - 734', 'Non AC Seater (2+3)', '15:10', '04h 30m', '19:40', 2.6, '155', '52 Seats available', 'West Bengal')
# Duplicate entry for row 2671, skipping.
# Inserting row 2672: (2673, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'SBSTC-DIGHA - KARUNAMOYEE - VIA DUNLOP - 15:20 (DIGHA) - 3244', 'Non AC Seater (2+3)', '15:20', '05h 00m', '20:20', 3.5, '170', '52 Seats available', 'West Bengal')
# Duplicate entry for row 2672, skipping.
# Inserting row 2673: (2674, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'SBSTC-DIGHA - GARIA - VIA - KOLKATA - 16:40 (FALTA DEPOT - 3704', 'Non AC Seater (2+3)', '16:40', '04h 30m', '21:10', 3.5, '155', '47 Seats available', 'West Bengal')
# Duplicate entry for row 2673, skipping.
# Inserting row 2674: (2675, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'SBSTC-DIGHA - KOLKATA - 17:15 (DIGHA DEPOT) - 1158', 'Non AC Seater (2+3)', '17:15', '04h 30m', '21:45', 1.0, '155', '52 Seats available', 'West Bengal')
# Duplicate entry for row 2674, skipping.
# Inserting row 2675: (2676, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Shyamoli Paribahan Pvt Ltd', 'VE A/C Seater (2+2)', '13:45', '05h 10m', '18:55', 4.3, '300', '38 Seats available', 'West Bengal')
# Duplicate entry for row 2675, skipping.
# Inserting row 2676: (2677, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Shyamoli Paribahan Pvt Ltd', 'Volvo A/C Seater (2+2)', '13:30', '04h 55m', '18:25', 4.3, '300', '26 Seats available', 'West Bengal')
# Duplicate entry for row 2676, skipping.
# Inserting row 2677: (2678, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Express Line', 'Volvo 9600 A/C Semi Sleeper (2+2)', '13:45', '04h 30m', '18:15', 4.6, '349', '33 Seats available', 'West Bengal')
# Duplicate entry for row 2677, skipping.
# Inserting row 2678: (2679, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Express Line', 'Volvo 9600 A/C Seater (2+2)', '10:25', '04h 55m', '15:20', 4.2, '379', '8 Seats available', 'West Bengal')
# Duplicate entry for row 2678, skipping.
# Inserting row 2679: (2680, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Shyamoli Paribahan Pvt Ltd', 'VE A/C Seater (2+2)', '09:50', '05h 30m', '15:20', 3.8, '400', '9 Seats available', 'West Bengal')
# Duplicate entry for row 2679, skipping.
# Inserting row 2680: (2681, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Greenline', 'Volvo A/C Seater (2+2)', '13:30', '04h 45m', '18:15', 4.4, '300', '31 Seats available', 'West Bengal')
# Duplicate entry for row 2680, skipping.
# Inserting row 2681: (2682, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Mayuri Express', 'AC Seater (2+2)', '10:30', '05h 00m', '15:30', 3.9, '270', '20 Seats available', 'West Bengal')
# Duplicate entry for row 2681, skipping.
# Inserting row 2682: (2683, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Mayuri Express', 'A/C Seater (2+3)', '11:15', '04h 45m', '16:00', 4.0, '280', '32 Seats available', 'West Bengal')
# Duplicate entry for row 2682, skipping.
# Inserting row 2683: (2684, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Shyamoli Paribahan Pvt Ltd', 'Volvo A/C Seater (2+2)', '13:15', '04h 30m', '17:45', 4.3, '300', '26 Seats available', 'West Bengal')
# Duplicate entry for row 2683, skipping.
# Inserting row 2684: (2685, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Express Line', 'Volvo A/C Seater (2+2)', '14:00', '04h 30m', '18:30', 4.5, '299', '28 Seats available', 'West Bengal')
# Duplicate entry for row 2684, skipping.
# Inserting row 2685: (2686, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Shyamoli Paribahan Pvt Ltd', 'Volvo A/C Seater (2+2)', '13:40', '04h 30m', '18:10', 4.1, '300', '34 Seats available', 'West Bengal')
# Duplicate entry for row 2685, skipping.
# Inserting row 2686: (2687, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Greenline', 'Volvo A/C Seater (2+2)', '13:40', '04h 45m', '18:25', 4.1, '300', '33 Seats available', 'West Bengal')
# Duplicate entry for row 2686, skipping.
# Inserting row 2687: (2688, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Monikanchan Bus Service', 'A/C Seater (2+3)', '13:30', '04h 15m', '17:45', 4.2, '375', '29 Seats available', 'West Bengal')
# Duplicate entry for row 2687, skipping.
# Inserting row 2688: (2689, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Rubi Paribahan  ', 'Volvo 9600 A/C Seater/Sleeper (2+1)', '12:50', '05h 00m', '17:50', 4.1, '400', '28 Seats available', 'West Bengal')
# Duplicate entry for row 2688, skipping.
# Inserting row 2689: (2690, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Royal Cruiser', 'Volvo A/C Seater (2+2)', '13:00', '04h 30m', '17:30', 3.8, '400', '29 Seats available', 'West Bengal')
# Duplicate entry for row 2689, skipping.
# Inserting row 2690: (2691, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Sree Jagannath Travels', 'A/C Seater Push Back (2+3)', '15:00', '05h 00m', '20:00', 4.2, '449', '28 Seats available', 'West Bengal')
# Duplicate entry for row 2690, skipping.
# Inserting row 2691: (2692, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Purusottam Travels', 'A/C Seater (2+3)', '08:10', '04h 50m', '13:00', 4.3, '299', '40 Seats available', 'West Bengal')
# Duplicate entry for row 2691, skipping.
# Inserting row 2692: (2693, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Snemita Paribahan(Shinjini)', 'A/C Seater (2+3)', '22:45', '05h 25m', '04:10', 3.6, '420', '24 Seats available', 'West Bengal')
# Duplicate entry for row 2692, skipping.
# Inserting row 2693: (2694, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'City Express (Shinjini)', 'AC Seater (2+3)', '22:45', '05h 25m', '04:10', 3.2, '420', '26 Seats available', 'West Bengal')
# Duplicate entry for row 2693, skipping.
# Inserting row 2694: (2695, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Snemita Paribahan', 'AC Seater (2+3)', '12:15', '04h 25m', '16:40', 4.0, '420', '50 Seats available', 'West Bengal')
# Duplicate entry for row 2694, skipping.
# Inserting row 2695: (2696, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Haimanti Bus Service', 'AC Seater (2+3)', '05:40', '04h 50m', '10:30', 3.2, '250', '20 Seats available', 'West Bengal')
# Duplicate entry for row 2695, skipping.
# Inserting row 2696: (2697, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Parameswar Travels', 'A/C Seater Push Back (2+3)', '09:30', '04h 45m', '14:15', 2.9, '340', '51 Seats available', 'West Bengal')
# Duplicate entry for row 2696, skipping.
# Inserting row 2697: (2698, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'City Express (Angel)', 'AC Seater (2+3)', '13:50', '04h 40m', '18:30', 3.5, '420', '31 Seats available', 'West Bengal')
# Duplicate entry for row 2697, skipping.
# Inserting row 2698: (2699, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Snemita Paribahan', 'A/C Seater / Sleeper (2+2)', '12:35', '05h 00m', '17:35', 3.6, '420', '35 Seats available', 'West Bengal')
# Duplicate entry for row 2698, skipping.
# Inserting row 2699: (2700, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Monikanchan Bus Service', 'A/C Seater (2+3)', '12:20', '04h 20m', '16:40', 3.9, '375', '22 Seats available', 'West Bengal')
# Duplicate entry for row 2699, skipping.
# Inserting row 2700: (2701, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Bengal Surface Transport', 'A/C Seater / Sleeper (2+2)', '10:55', '05h 00m', '15:55', 3.1, '319', '31 Seats available', 'West Bengal')
# Duplicate entry for row 2700, skipping.
# Inserting row 2701: (2702, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Ankita Paribahan (Haimanti)', 'A/C Seater Push Back (2+3)', '06:00', '04h 30m', '10:30', 3.0, '350', '27 Seats available', 'West Bengal')
# Duplicate entry for row 2701, skipping.
# Inserting row 2702: (2703, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Snemita Pariseba(Samanta)', 'A/C Seater Push Back (2+3)', '14:45', '04h 35m', '19:20', 2.5, '300', '33 Seats available', 'West Bengal')
# Duplicate entry for row 2702, skipping.
# Inserting row 2703: (2704, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Snemita Paribahan(Jackson)', 'AC Seater (2+2)', '13:40', '04h 50m', '18:30', 3.2, '420', '24 Seats available', 'West Bengal')
# Duplicate entry for row 2703, skipping.
# Inserting row 2704: (2705, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Satya Paribahan', 'A/C Seater (2+3)', '23:00', '04h 45m', '03:45', 2.9, '370', '19 Seats available', 'West Bengal')
# Duplicate entry for row 2704, skipping.
# Inserting row 2705: (2706, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Monikanchan Bus Service', 'Non AC Seater (2+3)', '11:40', '04h 35m', '16:15', 3.8, '215', '44 Seats available', 'West Bengal')
# Duplicate entry for row 2705, skipping.
# Inserting row 2706: (2707, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Snemita Parisheba (Manikanchan)', 'AC Seater (2+3)', '12:20', '04h 25m', '16:45', 3.1, '370', '20 Seats available', 'West Bengal')
# Duplicate entry for row 2706, skipping.
# Inserting row 2707: (2708, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Ankita Paribahan(Atithi)', 'A/C Seater (2+3)', '10:45', '05h 00m', '15:45', 3.2, '320', '29 Seats available', 'West Bengal')
# Duplicate entry for row 2707, skipping.
# Inserting row 2708: (2709, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'Haimanti Bus Service', 'AC Seater (2+3)', '09:50', '05h 25m', '15:15', 3.3, '350', '17 Seats available', 'West Bengal')
# Duplicate entry for row 2708, skipping.
# Inserting row 2709: (2710, 'Digha to Calcutta', 'https://www.redbus.in/bus-tickets/digha-to-kolkata', 'City Express (ANGEL)', 'AC Seater (2+2)', '10:15', '04h 30m', '14:45', 3.8, '450', '20 Seats available', 'West Bengal')
# Duplicate entry for row 2709, skipping.
# Inserting row 2710: (2711, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KARUNAMOYEE - BANKURA - VIA - DURGAPUR - 05:40 - 301', 'Non AC Seater (2+3)', '05:40', '05h 30m', '11:10', 3.7, '185', '27 Seats available', 'West Bengal')
# Duplicate entry for row 2710, skipping.
# Inserting row 2711: (2712, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KARUNAMOYEE - BANKURA - VIA - DURGAPUR - 06:40 - 305', 'Non AC Seater (2+3)', '06:40', '05h 30m', '12:10', 4.1, '185', '29 Seats available', 'West Bengal')
# Duplicate entry for row 2711, skipping.
# Inserting row 2712: (2713, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KARUNAMOYEE - BANKURA - VIA - DURGAPUR - 07:20 - 742', 'Non AC Seater (2+3)', '07:20', '05h 30m', '12:50', 3.3, '185', '47 Seats available', 'West Bengal')
# Duplicate entry for row 2712, skipping.
# Inserting row 2713: (2714, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KARUNAMOYEE - BANKURA - A/C - 07:30 - 1499', 'AC Seater (2+2)', '07:30', '05h 30m', '13:00', 3.5, '360', '1 Seat available', 'West Bengal')
# Duplicate entry for row 2713, skipping.
# Inserting row 2714: (2715, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KOLKATA - BAGMUNDI - 08:30 (BEL DEPOT) - 480', 'Non AC Seater (2+3)', '08:30', '04h 00m', '12:30', 2.5, '180', '44 Seats available', 'West Bengal')
# Duplicate entry for row 2714, skipping.
# Inserting row 2715: (2716, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KOLKATA - PURULIA - VIA - BANKURA - 12:00 (HWH DEP - 401', 'Non AC Seater (2+3)', '12:00', '04h 00m', '16:00', 3.8, '180', '38 Seats available', 'West Bengal')
# Duplicate entry for row 2715, skipping.
# Inserting row 2716: (2717, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KARUNAMOYEE - BANKURA - VIA - DURGAPUR - 12:00 - 310', 'Non AC Seater (2+3)', '12:00', '05h 30m', '17:30', 2.3, '185', '44 Seats available', 'West Bengal')
# Duplicate entry for row 2716, skipping.
# Inserting row 2717: (2718, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KOLKATA - PURULIA - VIA - BANKURA - 13:00 (PRL DEP - 290', 'Non AC Seater (2+3)', '13:00', '04h 00m', '17:00', 2.6, '180', '41 Seats available', 'West Bengal')
# Duplicate entry for row 2717, skipping.
# Inserting row 2718: (2719, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KOLKATA - BANKURA - 14:30 (Bankura Depot) - 2756', 'Non AC Seater (2+3)', '14:30', '04h 00m', '18:30', 2.2, '180', '51 Seats available', 'West Bengal')
# Duplicate entry for row 2718, skipping.
# Inserting row 2719: (2720, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KOLKATA - BANKURA - 15:30 (Bankura Depot) - 294', 'Non AC Seater (2+3)', '15:30', '04h 00m', '19:30', 2.5, '180', '52 Seats available', 'West Bengal')
# Duplicate entry for row 2719, skipping.
# Inserting row 2720: (2721, 'Kolkata to Bankura', 'https://www.redbus.in/bus-tickets/kolkata-to-bankura', 'SBSTC-KARUNAMOYEE - BANKURA - VIA - DURGAPUR - 17:30 - 311', 'Non AC Seater (2+3)', '17:30', '05h 30m', '23:00', 4.0, '185', '47 Seats available', 'West Bengal')
# Duplicate entry for row 2720, skipping.
